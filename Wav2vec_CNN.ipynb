# %% [markdown]
# # Download Dataset

# %%
! pip install -q kaggle

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns


import librosa 
import librosa.display

from IPython.display import Audio
plt.style.use('seaborn-white')

# %%
! kaggle datasets download -d ejlok1/toronto-emotional-speech-set-tess
# Out:
# Downloading toronto-emotional-speech-set-tess.zip to /content
#  96% 409M/428M [00:13<00:00, 20.4MB/s]
# 100% 428M/428M [00:14<00:00, 31.9MB/s]

# %%
# !unzip toronto-emotional-speech-set-tess.zip -d toronto-emotional-speech-set-tess
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_back_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bar_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_base_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bath_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bean_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_beg_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bite_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_boat_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bone_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_book_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_bought_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_burn_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cab_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_calm_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_came_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cause_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chain_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chair_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chalk_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chat_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_check_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cheek_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_chief_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_choice_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_cool_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dab_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_date_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dead_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_death_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_deep_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dime_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dip_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_ditch_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dodge_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_dog_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_doll_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_door_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fail_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fall_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_far_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fat_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_fit_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_five_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_food_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gap_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gas_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gaze_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_germ_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_get_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gin_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_goal_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_good_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_goose_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_gun_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_half_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hall_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hash_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hate_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_have_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_haze_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hire_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hit_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hole_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_home_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hurl_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_hush_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_jail_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_jar_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_join_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_judge_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_jug_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_juice_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_keen_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_keep_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_keg_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_kick_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_kill_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_king_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_kite_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_knock_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_late_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_laud_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_lean_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_learn_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_lease_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_lid_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_life_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_limb_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_live_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_loaf_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_long_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_lore_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_lose_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_lot_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_love_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_luck_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_make_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_match_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_merge_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_mess_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_met_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_mill_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_mob_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_mode_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_mood_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_moon_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_mop_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_mouse_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_nag_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_name_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_near_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_neat_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_nice_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_note_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_numb_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pad_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_page_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pain_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pass_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pearl_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_peg_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_perch_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_phone_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pick_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pike_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pole_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_pool_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_puff_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_rag_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_raid_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_rain_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_raise_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_rat_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_reach_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_read_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_red_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_ring_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_ripe_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_road_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_room_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_rose_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_rot_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_rough_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_rush_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_said_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_sail_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_search_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_seize_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_sell_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_shack_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_shall_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_shawl_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_sheep_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_shirt_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_should_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_shout_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_size_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_soap_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_soup_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_sour_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_south_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_sub_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_such_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_sure_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_take_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_talk_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_tape_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_team_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_tell_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_thin_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_third_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_thought_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_thumb_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_time_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_tip_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_tire_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_ton_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_tool_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_tough_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_turn_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_vine_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_voice_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_void_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_vote_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_wag_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_walk_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_wash_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_week_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_wheat_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_when_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_which_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_whip_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_white_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_wife_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_wire_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_witch_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_yearn_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_yes_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_young_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_angry/OAF_youth_angry.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_back_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_bar_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_base_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_bath_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_bean_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_beg_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_bite_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_boat_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_bone_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_book_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_bought_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_burn_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_cab_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_calm_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_came_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_cause_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_chain_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_chair_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_chalk_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_chat_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_check_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_cheek_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_chief_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_choice_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_cool_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_dab_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_date_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_dead_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_death_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_deep_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_dime_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_dip_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_ditch_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_dodge_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_dog_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_doll_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_door_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_fail_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_fall_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_far_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_fat_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_fit_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_five_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_food_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_gap_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_gas_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_gaze_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_germ_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_get_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_gin_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_goal_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_good_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_goose_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_gun_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_half_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hall_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hash_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hate_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_have_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_haze_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hire_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hit_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hole_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_home_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hurl_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_hush_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_jail_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_jar_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_join_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_judge_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_jug_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_juice_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_keen_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_keep_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_keg_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_kick_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_kill_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_king_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_kite_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_knock_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_late_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_laud_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_lean_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_learn_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_lease_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_lid_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_life_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_limb_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_live_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_loaf_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_long_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_lore_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_lose_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_lot_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_love_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_luck_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_make_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_match_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_merge_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_mess_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_met_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_mill_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_mob_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_mode_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_mood_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_moon_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_mop_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_mouse_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_nag_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_name_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_near_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_neat_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_nice_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_note_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_numb_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pad_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_page_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pain_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pass_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pearl_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_peg_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_perch_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_phone_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pick_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pike_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pole_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_pool_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_puff_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_rag_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_raid_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_rain_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_raise_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_rat_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_reach_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_read_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_red_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_ring_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_ripe_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_road_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_room_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_rose_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_rot_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_rough_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_rush_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_said_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_sail_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_search_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_seize_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_sell_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_shack_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_shall_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_shawl_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_sheep_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_shirt_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_should_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_shout_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_size_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_soap_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_soup_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_sour_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_south_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_sub_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_such_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_sure_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_take_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_talk_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_tape_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_team_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_tell_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_thin_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_third_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_thought_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_thumb_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_time_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_tip_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_tire_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_ton_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_tool_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_tough_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_turn_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_vine_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_voice_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_void_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_vote_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_wag_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_walk_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_wash_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_week_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_wheat_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_when_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_which_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_whip_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_white_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_wife_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_wire_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_witch_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_yearn_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_yes_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_young_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_disgust/OAF_youth_disgust.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_happy/OAF_back_happy.wav
#   inflating: toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/OAF_happy/OAF_bar_happy.wav
# ...
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_luck_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_make_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_match_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_merge_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mess_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_met_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mill_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mob_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mode_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mood_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_moon_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mop_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_mouse_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_nag_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_name_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_near_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_neat_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_nice_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_note_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_numb_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pad_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_page_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pain_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pass_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pearl_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_peg_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_perch_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_phone_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pick_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pike_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pole_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_pool_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_puff_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rag_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_raid_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rain_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_raise_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rat_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_reach_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_read_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_red_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ring_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ripe_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_road_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_room_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rose_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rot_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rough_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_rush_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_said_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sail_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_search_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_seize_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sell_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shack_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shall_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shawl_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sheep_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shirt_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_should_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_shout_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_size_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_soap_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_soup_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sour_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_south_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sub_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_such_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_sure_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_take_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_talk_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tape_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_team_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tell_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thin_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_third_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thought_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_thumb_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_time_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tip_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tire_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_ton_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tool_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_tough_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_turn_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_vine_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_voice_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_void_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_vote_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wag_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_walk_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wash_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_week_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wheat_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_when_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_which_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_whip_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_white_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wife_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_wire_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_witch_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_yearn_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_yes_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_young_sad.wav
#   inflating: toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/YAF_sad/YAF_youth_sad.wav

# %% [markdown]
# # Preprocessing

# %%
TESS = "../content/toronto-emotional-speech-set-tess/tess toronto emotional speech set data/TESS Toronto emotional speech set data/" #check

# %%
path = []
emotion = []
dir_list = os.listdir(TESS)

for i in dir_list:
    fname = os.listdir(TESS + i)   
    for f in fname:
        if i == 'OAF_angry' or i == 'YAF_angry':
            emotion.append('angry')
        elif i == 'OAF_disgust' or i == 'YAF_disgust':
            emotion.append('disgust')
        elif i == 'OAF_Fear' or i == 'YAF_fear':
            emotion.append('fear')
        elif i == 'OAF_happy' or i == 'YAF_happy':
            emotion.append('happy')
        elif i == 'OAF_neutral' or i == 'YAF_neutral':
            emotion.append('neutral')                                
        elif i == 'OAF_Pleasant_surprise' or i == 'YAF_pleasant_surprised':
            emotion.append('surprise')               
        elif i == 'OAF_Sad' or i == 'YAF_sad':
            emotion.append('sad')
        else:
            emotion.append('Unknown')
        path.append(TESS + i + "/" + f)

TESS_df = pd.DataFrame(emotion, columns = ['labels'])
TESS_df = pd.concat([TESS_df,pd.DataFrame(path, columns = ['path'])],axis=1)

# %%
labels = []
path = []


for i in range(len(TESS_df)):
  path.append(TESS_df['path'][i])
  labels.append(TESS_df['labels'][i])

d = {'labels': labels, 'path': path}
DF = pd.DataFrame(data=d)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder

all_labels = DF['labels'].values

encoder = OneHotEncoder()

encoded_labels = encoder.fit_transform(np.array(all_labels).reshape(-1,1)).toarray()

onehot = []
for item in encoded_labels:
  tmp = ''
  for i in range(len(item)):
    tmp = tmp + str(int(item[i]))
  onehot.append(tmp)

DF['onehot'] = onehot

# %%
DF = DF.sample(frac=1)
DF = DF.reset_index(drop=True)

# %%
maxx = 48000

# %%
def get_data(path):
  data1, sample_rate = librosa.load(path, duration=3, offset=0.5, res_type='kaiser_fast',sr=16000)

  #padding
  data = []
  for d in data1:
    data.append(float(d))
  for i in range(maxx- len(data1)):
    data.append(0)

  result = np.array(data)
  return result

# %%
notfound = []
Y = []
datas = []

i = 0
for path, emotion in zip(DF.path, DF.onehot):
  try:
    data = get_data(path)
    datas.append(data)
    Y.append(emotion)

  except:
    notfound.append([path,i])
  i = i+1   

X_np = np.array(datas)
print(f'Check shapes:\nFemale features: {X_np.shape}, labels: {len(Y)}')
# Out:
# Check shapes:
# Female features: (2800, 48000), labels: 2800

# %%
len(notfound)
# Out:
# 0

# %%
onehot = []
for l in Y:
  tmp=[]
  for c in l:
    tmp.append(int(c))
  onehot.append(tmp)
onehot_np = np.array(onehot)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_np, onehot_np, random_state=0, test_size=0.20, shuffle=True)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((2240, 48000), (2240, 7), (560, 48000), (560, 7))

# %% [markdown]
# # Feature Extraction and Augmentation

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.3-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 4.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 51.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 49.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.21.3

# %%
from transformers import AutoTokenizer, AutoFeatureExtractor
import torch
from transformers import Wav2Vec2FeatureExtractor

# import feature extractor, tokenizer
#tokenizer = AutoTokenizer.from_pretrained("facebook/wav2vec2-base-960h")

#tested tekrari mide too har satr #feature_extractor = AutoFeatureExtractor.from_pretrained("facebook/wav2vec2-base-960h")
#tested sefr mide feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("superb/wav2vec2-base-superb-ks")
#tested sefr mide feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("anton-l/wav2vec2-base-superb-sd")
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("superb/hubert-large-superb-er")
# Out:
# Downloading preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]

# %%
def extract_features(data,sample_rate = 16000):

  encodings = feature_extractor(data, sampling_rate=16000, padding=True, return_tensors="pt")
  result = np.array(encodings['input_values'][0])
  return result

# %%
def noise(data):
    noise_amp = 0.04*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.70):
    return librosa.effects.time_stretch(data, rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate = 16000, pitch_factor=0.8):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

def higher_speed(data, speed_factor = 1.25):
    return librosa.effects.time_stretch(data, speed_factor)

def lower_speed(data, speed_factor = 0.75):
    return librosa.effects.time_stretch(data, speed_factor)

# %%
empty = np.zeros(48000)
Augmented_train_data = []
Augmented_train_label = []

for i in range(len(x_train)):
  res1 = extract_features(x_train[i])
  #result = np.array(res1)
  Augmented_train_data.append(res1)
  Augmented_train_label.append(y_train[i])
  
  # noise_data = noise(x_train[i])
  # if noise_data.all() != empty.all():
  #   res2 = extract_features(noise_data)
  #   #result = np.array(res2)
  #   Augmented_train_data.append(res2)
  #   Augmented_train_label.append(y_train[i])

  shift_data = shift(x_train[i])
  if shift_data.all() != empty.all():
    res2 = extract_features(shift_data)
    #result = np.array(res2)
    Augmented_train_data.append(res2)
    Augmented_train_label.append(y_train[i])

  # pitch_data = pitch(x_train[i])
  # if pitch_data.all() != empty.all():
  #   res2 = extract_features(pitch_data)
  #   #result = np.array(res2)
  #   Augmented_train_data.append(res2)
  #   Augmented_train_label.append(y_train[i])

# %%
np.array(Augmented_train_data).shape,len(Augmented_train_label)
# Out:
# ((2240, 48000), 2240)

# %%
test_data = []
test_label = []

for i in range(len(x_test)):
  res1 = extract_features(x_test[i])
  result = np.array(res1)
  test_data.append(result)
  test_label.append(y_test[i])

# %%
np.array(test_data).shape,len(test_label)
# Out:
# ((560, 48000), 560)

# %%
df = {'data': Augmented_train_data, 'label': Augmented_train_label}
train_aug = pd.DataFrame(data=df)

# %%
train_aug = train_aug.sample(frac=1)
train_aug = train_aug.reset_index(drop=True)

# %%
train_features = np.asarray(train_aug['data'])
train_labels__ = np.asarray(train_aug['label'])
train_labels_ = []
for l in train_labels__:
  train_labels_.append(np.asarray(l).astype(np.float32))
train_labels = np.asarray(train_labels_).astype(np.float32)

test_features = np.asarray(test_data).astype(np.float32)
test_labels = np.asarray(test_label).astype(np.float32)

# %%
for t in train_features:
  if len(t) != 48000:
    print(len(t))

# %%
train_features.shape,train_labels.shape
# Out:
# ((2240,), (2240, 7))

# %%
train_features_list = []
for t in train_features:
  train_features_list.append(np.asarray(t).astype(np.float32))

# %%
train_features_np = np.asarray(train_features_list).astype(np.float32)

# %%
train_features_np.shape
# Out:
# (2240, 48000)

# %% [markdown]
# # Classification

# %%
import tensorflow as tf
from tensorflow import keras

from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization, AveragePooling1D
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Create a MirroredStrategy.
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 1

# %%
with strategy.scope():
    
    def build_model(in_shape):
        
        model=Sequential()
        model.add(Conv1D(256, kernel_size=6, strides=1, padding='same', activation='relu', input_shape=(in_shape, 1)))
        model.add(AveragePooling1D(pool_size=4, strides = 2, padding = 'same'))
        model.add(Dropout(0.2))

        model.add(Conv1D(128, kernel_size=6, strides=1, padding='same', activation='relu', input_shape=(in_shape, 1)))
        model.add(AveragePooling1D(pool_size=4, strides = 2, padding = 'same'))
        model.add(Dropout(0.2))

        model.add(Conv1D(128, kernel_size=6, strides=1, padding='same', activation='relu'))
        model.add(AveragePooling1D(pool_size=4, strides = 2, padding = 'same'))
        model.add(Dropout(0.2))

        model.add(Conv1D(64, kernel_size=6, strides=1, padding='same', activation='relu'))
        model.add(AveragePooling1D(pool_size=4, strides = 2, padding = 'same'))
        model.add(Dropout(0.2))

        model.add(Conv1D(32, kernel_size=6, strides=1, padding='same', activation='relu'))
        model.add(MaxPooling1D(pool_size=4, strides = 2, padding = 'same'))
        
        model.add(Flatten())
        model.add(Dense(units=32, activation='relu'))
        model.add(Dropout(0.3))

        model.add(Dense(units=7, activation='softmax'))
        model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
          
        
        return model

# %%
def model_build_summary(mod_dim):
    model = build_model(mod_dim)
    model.summary()
    
    return model

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=4, min_lr=0.000001)

batch_size = 32
n_epochs = 30

# %%
total_model = model_build_summary(train_features_np.shape[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 48000, 256)        1792
#
#  average_pooling1d (AverageP  (None, 24000, 256)       0
#  ooling1D)
#
#  dropout (Dropout)           (None, 24000, 256)        0
#
#  conv1d_1 (Conv1D)           (None, 24000, 128)        196736
#
#  average_pooling1d_1 (Averag  (None, 12000, 128)       0
#  ePooling1D)
#
#  dropout_1 (Dropout)         (None, 12000, 128)        0
#
#  conv1d_2 (Conv1D)           (None, 12000, 128)        98432
#
#  average_pooling1d_2 (Averag  (None, 6000, 128)        0
#  ePooling1D)
#
#  dropout_2 (Dropout)         (None, 6000, 128)         0
#
#  conv1d_3 (Conv1D)           (None, 6000, 64)          49216
#
#  average_pooling1d_3 (Averag  (None, 3000, 64)         0
#  ePooling1D)
#
#  dropout_3 (Dropout)         (None, 3000, 64)          0
#
#  conv1d_4 (Conv1D)           (None, 3000, 32)          12320
#
#  max_pooling1d (MaxPooling1D  (None, 1500, 32)         0
#  )
#
#  flatten (Flatten)           (None, 48000)             0
#
#  dense (Dense)               (None, 32)                1536032
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 1,894,759
# Trainable params: 1,894,759
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = tf.convert_to_tensor(train_features_np, dtype=tf.float32)
y_train = tf.convert_to_tensor(train_labels, dtype=tf.float32)
X_test = tf.convert_to_tensor(test_features, dtype=tf.float32)
y_test = tf.convert_to_tensor(test_labels, dtype=tf.float32)

# %%
history = total_model.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs,
                          validation_data=(X_test, y_test),
                          callbacks=[rlrp])
# Out:
# Epoch 1/30
# 70/70 [==============================] - 37s 386ms/step - loss: 1.3668 - accuracy: 0.4652 - val_loss: 0.7887 - val_accuracy: 0.7804 - lr: 0.0010
# Epoch 2/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.7738 - accuracy: 0.7013 - val_loss: 0.3066 - val_accuracy: 0.9107 - lr: 0.0010
# Epoch 3/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.4816 - accuracy: 0.8250 - val_loss: 0.2368 - val_accuracy: 0.9286 - lr: 0.0010
# Epoch 4/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.3900 - accuracy: 0.8558 - val_loss: 0.1916 - val_accuracy: 0.9339 - lr: 0.0010
# Epoch 5/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.2469 - accuracy: 0.9085 - val_loss: 0.1255 - val_accuracy: 0.9500 - lr: 0.0010
# Epoch 6/30
# 70/70 [==============================] - 26s 376ms/step - loss: 0.2295 - accuracy: 0.9134 - val_loss: 0.1096 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 7/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.2114 - accuracy: 0.9156 - val_loss: 0.1471 - val_accuracy: 0.9500 - lr: 0.0010
# Epoch 8/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.1931 - accuracy: 0.9299 - val_loss: 0.1480 - val_accuracy: 0.9536 - lr: 0.0010
# Epoch 9/30
# 70/70 [==============================] - 26s 376ms/step - loss: 0.2391 - accuracy: 0.9152 - val_loss: 0.1911 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 10/30
# 70/70 [==============================] - 26s 376ms/step - loss: 0.1536 - accuracy: 0.9424 - val_loss: 0.0795 - val_accuracy: 0.9643 - lr: 0.0010
# Epoch 11/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.1898 - accuracy: 0.9272 - val_loss: 0.1160 - val_accuracy: 0.9643 - lr: 0.0010
# Epoch 12/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.1229 - accuracy: 0.9536 - val_loss: 0.0738 - val_accuracy: 0.9750 - lr: 0.0010
# Epoch 13/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.1009 - accuracy: 0.9549 - val_loss: 0.0957 - val_accuracy: 0.9696 - lr: 0.0010
# Epoch 14/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.1051 - accuracy: 0.9558 - val_loss: 0.1087 - val_accuracy: 0.9714 - lr: 0.0010
# Epoch 15/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0957 - accuracy: 0.9598 - val_loss: 0.1069 - val_accuracy: 0.9643 - lr: 0.0010
# Epoch 16/30
# 70/70 [==============================] - 26s 376ms/step - loss: 0.1401 - accuracy: 0.9478 - val_loss: 0.1264 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 17/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0944 - accuracy: 0.9634 - val_loss: 0.1147 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 18/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0997 - accuracy: 0.9589 - val_loss: 0.1361 - val_accuracy: 0.9714 - lr: 0.0010
# Epoch 19/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0995 - accuracy: 0.9625 - val_loss: 0.1025 - val_accuracy: 0.9768 - lr: 0.0010
# Epoch 20/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0899 - accuracy: 0.9688 - val_loss: 0.0825 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 21/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0959 - accuracy: 0.9665 - val_loss: 0.1092 - val_accuracy: 0.9804 - lr: 0.0010
# Epoch 22/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0997 - accuracy: 0.9670 - val_loss: 0.0758 - val_accuracy: 0.9821 - lr: 0.0010
# Epoch 23/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0702 - accuracy: 0.9732 - val_loss: 0.0693 - val_accuracy: 0.9857 - lr: 0.0010
# Epoch 24/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0717 - accuracy: 0.9754 - val_loss: 0.0808 - val_accuracy: 0.9857 - lr: 0.0010
# Epoch 25/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0715 - accuracy: 0.9768 - val_loss: 0.0867 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 26/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0616 - accuracy: 0.9772 - val_loss: 0.0767 - val_accuracy: 0.9821 - lr: 0.0010
# Epoch 27/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0520 - accuracy: 0.9786 - val_loss: 0.1159 - val_accuracy: 0.9839 - lr: 0.0010
# Epoch 28/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0479 - accuracy: 0.9875 - val_loss: 0.1198 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 29/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0725 - accuracy: 0.9728 - val_loss: 0.1310 - val_accuracy: 0.9804 - lr: 0.0010
# Epoch 30/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.0473 - accuracy: 0.9826 - val_loss: 0.1571 - val_accuracy: 0.9786 - lr: 0.0010

# %% [markdown]
# # ٍExample

# %%
# def create_waveplot(data, sr):
#     plt.figure(figsize=(10, 3))
#     plt.title(f'Waveplot for audio', size=15)
#     librosa.display.waveplot(data, sr=sr)
#     plt.show()
# path = DF['path'][6]
# data, sampling_rate = librosa.load(path)
# #create_waveplot(data, sampling_rate)
# Audio(path)
# data1 = shift(data)
# from __future__ import print_function
# import scipy.io.wavfile as wavf
# import numpy as np

# if __name__ == "__main__":

#     fs = 16000
#     out_f = 'out.wav'

#     wavf.write(out_f, fs, data1)
# Audio(out_f)
